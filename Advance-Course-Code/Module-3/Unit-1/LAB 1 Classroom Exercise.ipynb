# %% [markdown]
# <span style="color:black;font-size: 30px; font-family: Arial; font-weight: bold;">EDUNET FOUNDATION-Classroom Exercise Notebook</span>

# %% [markdown]
# <span style="color:black;font-size: 30px; font-family: Arial; font-weight: bold;"> Lab 1 -   First neural network with keras  </span>

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/93/21/9b035a4f823d6aee2917c75415be9a95861ff3d73a0a65e48edbf210cec1/tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting tensorflow-intel==2.15.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-intel==2.15.0 from https://files.pythonhosted.org/packages/4c/48/1a5a15517f18eaa4ff8d598b1c000300b20c1bb0e624539d702117a0c369/tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dev\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dev\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.28.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\dev\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dev\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dev\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dev\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dev\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dev\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dev\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dev\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dev\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dev\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dev\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dev\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dev\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dev\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dev\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Using cached tensorflow-2.15.0-cp311-cp311-win_amd64.whl (2.1 kB)
# Using cached tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl (300.9 MB)
# Installing collected packages: tensorflow-intel, tensorflow
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Dev\\anaconda3\\Lib\\site-packages\\tensorflow\\compiler\\mlir\\quantization\\tensorflow\\python\\pywrap_quantize_model.pyd'
# Consider using the `--user` option or check the permissions.

# %%
from numpy import genfromtxt
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
 dataset = genfromtxt('diabetes.csv', delimiter=',')

# %%
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# define the keras model
model = Sequential()
model.add(Dense(8, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=30, batch_size=5)
# Out:
# Epoch 1/30
# 154/154 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.6437
# Epoch 2/30
# 154/154 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6502
# Epoch 3/30
# 154/154 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6502
# Epoch 4/30
# 154/154 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6502
# Epoch 5/30
# 154/154 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6502
# Epoch 6/30
# 154/154 [==============================] - 0s 993us/step - loss: nan - accuracy: 0.6502
# Epoch 7/30
# 154/154 [==============================] - 0s 934us/step - loss: nan - accuracy: 0.6502
# Epoch 8/30
# 154/154 [==============================] - 0s 945us/step - loss: nan - accuracy: 0.6502
# Epoch 9/30
# 154/154 [==============================] - 0s 989us/step - loss: nan - accuracy: 0.6502
# Epoch 10/30
# 154/154 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6502
# Epoch 11/30
# 154/154 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6502
# Epoch 12/30
# 154/154 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6502
# Epoch 13/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Epoch 14/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Epoch 15/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Epoch 16/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Epoch 17/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 18/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 19/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 20/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 21/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Epoch 22/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Epoch 23/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Epoch 24/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 25/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Epoch 26/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 27/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 28/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 29/30
# 154/154 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.6502
# Epoch 30/30
# 154/154 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 25/25 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.6502
# Accuracy: 65.02
